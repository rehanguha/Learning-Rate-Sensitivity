# %%
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

# %%
df = pd.read_csv("output/CIFAR10_LR_COPY.csv")

# %%
df
# Out:
#     optimizer     lr  epoch  accuracy      loss  test_accuracy  test_loss
# 0         SGD  0.001    200   0.80468  0.563971         0.6805   1.035302
# 1         SGD  0.002    200   0.98406  0.079354         0.6813   1.863416
# 2         SGD  0.003    200   1.00000  0.003995         0.6825   2.960282
# 3         SGD  0.004    200   1.00000  0.001621         0.6853   3.276943
# 4         SGD  0.005    200   1.00000  0.000876         0.6961   3.301976
# ..        ...    ...    ...       ...       ...            ...        ...
# 695     Nadam  0.096    200   0.10000  2.325119         0.1000   2.325117
# 696     Nadam  0.097    200   0.10000  2.309702         0.1000   2.309700
# 697     Nadam  0.098    200   0.10000  2.311906         0.1000   2.311906
# 698     Nadam  0.099    200   0.10000  2.313456         0.1000   2.313458
# 699     Nadam  0.100    200   0.10000  2.316324         0.1000   2.316326
#
# [700 rows x 7 columns]

# %%
df.optimizer.value_counts()
# Out:
# Adamax      100
# Adagrad     100
# Adam        100
# Adadelta    100
# RMSprop     100
# Nadam       100
# SGD         100
# Name: optimizer, dtype: int64

# %%
sns.lineplot(data=df[df['optimizer'].isin(['SGD',
                                          'Adam',
                                          'Adadelta',
                                          'RMSprop',
                                          'Nadam',
                                          'Adagrad',
                                          'Adamax'])], 
                x='lr', 
                y='test_accuracy', hue="optimizer")
# Out:
# <AxesSubplot:xlabel='lr', ylabel='test_accuracy'>

# %%
sns.lineplot(data=df[df['optimizer'].isin(['Adagrad',
                                          'Adadelta', 'SGD'])], 
                x='lr', 
                y='test_accuracy', hue="optimizer")
# Out:
# <AxesSubplot:xlabel='lr', ylabel='test_accuracy'>

# %%
sns.lineplot(data=df[df['optimizer'].isin(['RMSprop',
                                          'Adam',
                                          'Nadam',''])], 
                x='lr', 
                y='accuracy', hue="optimizer")
# Out:
# <AxesSubplot:xlabel='lr', ylabel='accuracy'>

# %%
sns.lineplot(data=df[df['optimizer'].isin(['SGD',
                                          'Adadelta',
                                          'Adagrad',
                                          'Adamax'])], 
                x='lr', 
                y='test_accuracy', hue="optimizer")
plt.xlabel('Learning Rate')
plt.ylabel('Test Accuracy')
# Out:
# Text(0, 0.5, 'Test Accuracy')

# %%
sns.lineplot(data=df[df['optimizer'].isin(['SGD',
                                          'Adadelta',
                                          'Adagrad',
                                          'Adamax'])], 
                x='lr', 
                y='accuracy', hue="optimizer")
plt.xlabel('Learning Rate')
plt.ylabel('Train Accuracy')
# Out:
# Text(0, 0.5, 'Train Accuracy')

# %%
fig = plt.figure(figsize=(10,600))

fig, ax = plt.subplots(ncols=2, 
                       sharex=True, 
                       sharey=False, 
                       constrained_layout=True,
                       figsize=(15,5))


sns.lineplot(data=df[df['optimizer'].isin(['Adagrad',
                                          'Adadelta','SGD'])], 
                x='lr', 
                y='accuracy', hue="optimizer", ax=ax[0])
ax[0].set_ylabel("Train Accuracy")
ax[0].set_xlabel("Learning Rate")
ax[0].legend(title='Optimizers')
ax[0].title.set_text("Train Accuracy vs. LR")
ax[0].xaxis.set_major_formatter(FormatStrFormatter('%.3f'))
plt.xticks(np.arange(0, 0.101, 0.01))


sns.lineplot(data=df[df['optimizer'].isin(['Adagrad',
                                          'Adadelta', 'SGD'])], 
                x='lr', 
                y='test_accuracy', hue="optimizer", ax=ax[1])
ax[1].set_ylabel("Test Accuracy")
ax[1].set_xlabel("Learning Rate")
ax[1].legend(title='Optimizers')
ax[1].title.set_text("Test Accuracy vs. LR")

# %%
fig = plt.figure(figsize=(10,600))



fig, ax = plt.subplots(ncols=2, 
                       sharex=True, 
                       sharey=False, 
                       constrained_layout=True,
                       figsize=(15,5))


sns.lineplot(data=df[df['optimizer'].isin(['RMSprop',
                                          'Adam',
                                          'Nadam','Adamax'])], 
                x='lr', 
                y='accuracy', hue="optimizer", ax=ax[0])
ax[0].set_ylabel("Train Accuracy")
ax[0].set_xlabel("Learning Rate")
ax[0].legend(title='Optimizers')
ax[0].title.set_text("Train Accuracy vs. LR")
ax[0].xaxis.set_major_formatter(FormatStrFormatter('%.3f'))
plt.xticks(np.arange(0, 0.101, 0.01))


sns.lineplot(data=df[df['optimizer'].isin(['RMSprop',
                                          'Adam',
                                          'Nadam','Adamax'])], 
                x='lr', 
                y='test_accuracy', hue="optimizer", ax=ax[1])
ax[1].set_ylabel("Test Accuracy")
ax[1].set_xlabel("Learning Rate")
ax[1].legend(title='Optimizers')
ax[1].title.set_text("Test Accuracy vs. LR")

# %%
df[df['optimizer']=='SGD']
# Out:
#    optimizer     lr  epoch  accuracy      loss  test_accuracy  test_loss
# 0        SGD  0.001    200   0.80468  0.563971         0.6805   1.035302
# 1        SGD  0.002    200   0.98406  0.079354         0.6813   1.863416
# 2        SGD  0.003    200   1.00000  0.003995         0.6825   2.960282
# 3        SGD  0.004    200   1.00000  0.001621         0.6853   3.276943
# 4        SGD  0.005    200   1.00000  0.000876         0.6961   3.301976
# ..       ...    ...    ...       ...       ...            ...        ...
# 95       SGD  0.096    200   0.10002  2.303336         0.0999   2.303394
# 96       SGD  0.097    200   0.10010  2.302829         0.1000   2.303488
# 97       SGD  0.098    200   0.10000  2.303229         0.1000   2.303230
# 98       SGD  0.099    200   0.10000  2.303543         0.1000   2.303543
# 99       SGD  0.100    200   0.10002  2.302889         0.1000   2.303026
#
# [100 rows x 7 columns]
